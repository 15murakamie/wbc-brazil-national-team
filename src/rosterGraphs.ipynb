# %%
# pip install -U kaleido

# %% [markdown]
# ### Importar o excel enriquecido

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Baseball/WBC/rostersBrasilTreated.xlsx'
df = pd.read_excel(file_path)
df.head()
# Out:
#    Index  anoTorneio pais              nome    posicao             time  \
# 0   96.0        2012  BRA      Alan Fanhoni  Infielder                -
# 1  114.0        2012  BRA      Andre Rienzo    Pitcher  White Sox Minor
# 2    NaN        2012  BRA     Barry Larkin     Manager                -
# 3  100.0        2012  BRA      Bruno Hirata    Catcher                -
# 4  120.0        2012  BRA  Carlos Yoshimura    Pitcher                -
#
#       nivel numeroCamiseta batThrow altura  ... idade torneio isMLB isNPB  \
# 0         -             33      L/R   6'4"  ...    21       Q   NaN   NaN
# 1  Triple A             25      R/R   6'3"  ...    24       Q   1.0   NaN
# 2         -              -        -      -  ...    48       Q   1.0   NaN
# 3         -             26      R/R   5'7"  ...    24       Q   NaN   NaN
# 4         -             15      R/R   5'9"  ...    28       Q   NaN   NaN
#
#   isKBO isMEX isTWN isVEN isMiLB isJPIND
# 0   NaN   NaN   NaN   NaN    NaN     1.0
# ...

# %% [markdown]
# ### Criando os datasets de referência:
#
#
# *   Jogador por campeonato - df_event_players
# *   Lista de jogadores - df_player_list
# *   Técnico por campeonato - df_event_coaches
# *   Lista de técnicos - df_coach_list

# %%
# Lista de posições de jogadores
player_position = ['Pitcher', 'Catcher', 'Infielder', 'Outfielder']

# Colunas que você quer manter - por evento
byEventColumns = ['anoTorneio', 'nome', 'posicao','time','nivel',
                  'altura_m', 'peso_kg', 'bat', 'throw', 'idade',
                  'torneio']

# Colunas que você quer manter - por jogador
byPlayerColumns = ['nome','localNascimento', 'isMLB', 'isNPB', 'isKBO', 'isMEX','isTWN', 'isVEN', 'isMiLB', 'isJPIND']

# %%
# Gerando df de jogadores por evento
df_events_player = df[df["posicao"].isin(player_position)][byEventColumns].copy()
df_events_player.head(5)
# Out:
#    anoTorneio              nome    posicao             time     nivel  \
# 0        2012      Alan Fanhoni  Infielder                -         -
# 1        2012      Andre Rienzo    Pitcher  White Sox Minor  Triple A
# 3        2012      Bruno Hirata    Catcher                -         -
# 4        2012  Carlos Yoshimura    Pitcher                -         -
# 5        2012    Daniel Missaki    Pitcher              NaN       NaN
#
#   altura_m peso_kg bat throw idade torneio
# 0     1.93    99.8   L     R    21       Q
# 1     1.91    86.2   R     R    24       Q
# 3      1.7    87.1   R     R    24       Q
# 4     1.75    74.8   R     R    28       Q
# 5     1.83    77.1   R     R    16       Q

# %%
# Gerando df de treinadores por evento
df_events_coach = df[~df["posicao"].isin(player_position)][byEventColumns].copy()
df_events_coach.head(5)
# Out:
#     anoTorneio              nome  posicao time nivel altura_m peso_kg bat  \
# 2         2012     Barry Larkin   Manager    -     -        -       -   -
# 9         2012         Go Kuroki    Coach    -     -        -       -   -
# 18        2012  Marcos Guimaraes    Coach    -     -        -       -   -
# 20        2012   Mitsuyoshi Sato    Coach    -     -        -       -   -
# 28        2012  Ricardo Matumaru    Coach    -     -        -       -   -
#
#    throw idade torneio
# 2      -    48       Q
# 9      -     -       Q
# 18     -    28       Q
# 20     -    66       Q
# 28     -     -       Q

# %%
# Gerando df por jogador
df_player_list = df[df["posicao"].isin(player_position)][byPlayerColumns].drop_duplicates()
df_player_list.head(5)
# Out:
#                nome    localNascimento  isMLB  isNPB  isKBO  isMEX  isTWN  \
# 0      Alan Fanhoni  Sao Paulo, Brazil    NaN    NaN    NaN    NaN    NaN
# 1      Andre Rienzo  Sao Paulo, Brazil    1.0    NaN    NaN    1.0    NaN
# 3      Bruno Hirata  Sao Paulo, Brazil    NaN    NaN    NaN    NaN    NaN
# 4  Carlos Yoshimura  Sao Paulo, Brazil    NaN    NaN    NaN    NaN    NaN
# 5    Daniel Missaki    Shizuoka, Japan    NaN    NaN    NaN    1.0    NaN
#
#    isVEN  isMiLB  isJPIND
# 0    NaN     NaN      1.0
# 1    1.0     1.0      NaN
# 3    NaN     NaN      1.0
# 4    NaN     NaN      1.0
# 5    NaN     1.0      NaN

# %%
# Gerando df por treinador
df_coach_list = df[~df["posicao"].isin(player_position)][byPlayerColumns].drop_duplicates()
df_coach_list.head(5)
# Out:
#                 nome localNascimento  isMLB  isNPB  isKBO  isMEX  isTWN  \
# 2      Barry Larkin        Ohio, USA    1.0    NaN    NaN    NaN    NaN
# 9          Go Kuroki               -    NaN    NaN    NaN    NaN    NaN
# 18  Marcos Guimaraes          Brazil    NaN    NaN    NaN    NaN    NaN
# 20   Mitsuyoshi Sato    Aichi, Japan    NaN    NaN    NaN    NaN    NaN
# 28  Ricardo Matumaru               -    NaN    NaN    NaN    NaN    NaN
#
#     isVEN  isMiLB  isJPIND
# 2     NaN     NaN      NaN
# 9     NaN     NaN      NaN
# 18    NaN     NaN      NaN
# 20    NaN     NaN      NaN
# 28    NaN     NaN      NaN

# %% [markdown]
# ### Gerando as visões

# %% [markdown]
# #### Desempenho Macro da Seleção Brasileira

# %%
# Dados
data = {
    "anoTorneio": [2012, 2013, 2016, 2022, 2025],
    "tpEvento": ['Qualifier', 'Main', 'Qualifier', 'Qualifier', 'Qualifier'],
    "jogos": [3, 3, 3, 4, 4],
    "vitoria": [3, 0, 1, 2, 3],
    "derrota": [0, 3, 2, 2, 1],
    "corridasAnotadas": [11, 7, 13, 17, 27],
    "corridasCedidas": [3, 15, 5, 15, 18],
    "rebatidas": [31, 21, 28, 27, 36],
    "rebatidasCedidas": [17, 21, 13, 25, 29],
    "erros": [4, 1, 4, 1, 3]
}

df_event = pd.DataFrame(data)
df_event
# Out:
#    anoTorneio   tpEvento  jogos  vitoria  derrota  corridasAnotadas  \
# 0        2012  Qualifier      3        3        0                11
# 1        2013       Main      3        0        3                 7
# 2        2016  Qualifier      3        1        2                13
# 3        2022  Qualifier      4        2        2                17
# 4        2025  Qualifier      4        3        1                27
#
#    corridasCedidas  rebatidas  rebatidasCedidas  erros
# 0                3         31                17      4
# 1               15         21                21      1
# 2                5         28                13      4
# 3               15         27                25      1
# 4               18         36                29      3

# %%
df_event
# Out:
#    anoTorneio   tpEvento  jogos  vitoria  derrota  corridasAnotadas  \
# 0        2012  Qualifier      3        3        0                11
# 1        2013       Main      3        0        3                 7
# 2        2016  Qualifier      3        1        2                13
# 3        2022  Qualifier      4        2        2                17
# 4        2025  Qualifier      4        3        1                27
#
#    corridasCedidas  rebatidas  rebatidasCedidas  erros
# 0                3         31                17      4
# 1               15         21                21      1
# 2                5         28                13      4
# 3               15         27                25      1
# 4               18         36                29      3

# %% [markdown]
# #### País de nascimento jogadores e treinadores

# %%
df_player_list["paisNascimento"] = df_player_list["localNascimento"].dropna().apply(lambda x: x.split(",")[-1].strip())

# Contar por país
player_birth_country = df_player_list["paisNascimento"].value_counts().reset_index()
player_birth_country.columns = ["pais", "quantidade"]
player_birth_country
# Out:
#         pais  quantidade
# 0     Brazil          60
# 1        USA          10
# 2       Cuba           4
# 3      Japan           3
# 4  Venezuela           1

# %%
df_coach_list["paisNascimento"] = df_coach_list["localNascimento"].dropna().apply(lambda x: x.split(",")[-1].strip())

# Contar por país
coach_birth_country = df_coach_list["paisNascimento"].value_counts().reset_index()
coach_birth_country.columns = ["pais", "quantidade"]
coach_birth_country
# Out:
#      pais  quantidade
# 0  Brazil           8
# 1     USA           4
# 2       -           3
# 3   Japan           1

# %%
merge_birth_country = pd.merge(
    player_birth_country,
    coach_birth_country,
    on="pais",
    how="outer",
    suffixes=("_jogadores", "_tecnicos")
).fillna(0)


merge_birth_country["quantidade_jogadores"] = merge_birth_country["quantidade_jogadores"].astype(int)
merge_birth_country["quantidade_tecnicos"] = merge_birth_country["quantidade_tecnicos"].astype(int)
merge_birth_country = merge_birth_country.rename(columns={"pais": "paisOrigem"})
merge_birth_country = merge_birth_country.rename(columns={"quantidade_jogadores": "jogadores"})
merge_birth_country = merge_birth_country.rename(columns={"quantidade_tecnicos": "tecnicos"})
merge_birth_country = merge_birth_country.sort_values(by="jogadores", ascending=False)

merge_birth_country
# Out:
#   paisOrigem  jogadores  tecnicos
# 1     Brazil         60         8
# 4        USA         10         4
# 2       Cuba          4         0
# 3      Japan          3         1
# 5  Venezuela          1         0
# 0          -          0         3

# %%
import plotly.graph_objects as go

# Criar mapa base com choropleth
fig = px.choropleth(
    player_birth_country,
    locations="pais",
    locationmode="country names",
    color="quantidade",
    color_continuous_scale="Viridis",
    title="Jogadores da Seleção Brasileira por País de Nascimento",
    hover_data={}  # REMOVE os tooltips
)

# Remover hover do choropleth
fig.update_traces(hoverinfo="skip", showscale=True)

# Adicionar os textos com a quantidade sobre os países
# Usamos scatter_geo com modo "text"
fig.add_trace(
    go.Scattergeo(
        locations=player_birth_country["pais"],
        locationmode="country names",
        text=player_birth_country["quantidade"].astype(str),
        mode="text",
        showlegend=False
    )
)

# Ajuste visual
fig.update_geos(
    showcountries=True,
    fitbounds="locations",
)

fig.update_layout(
    margin={"r":0,"t":40,"l":0,"b":0}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Participações por jogador e treinador

# %%
# Participação por jogador
player_participation = df_events_player.groupby("nome").size().reset_index(name="participacoes")
# Participação por treinador
coach_participation = df_events_coach.groupby("nome").size().reset_index(name="participacoes")


# Fazer o merge (junção) dos dois DataFrames pela coluna 'nome'
merged_participation = pd.merge(
    player_participation,
    coach_participation,
    on="nome",
    how="outer",  # Garante que quem participou só como jogador ou só como treinador também apareça
    suffixes=("_player", "_coach")
)

# Preencher valores ausentes com 0
merged_participation["participacoes_player"] = merged_participation["participacoes_player"].fillna(0).astype(int)
merged_participation["participacoes_coach"] = merged_participation["participacoes_coach"].fillna(0).astype(int)

# Criar coluna de total de participações
merged_participation["participacoes_total"] = (
    merged_participation["participacoes_player"] + merged_participation["participacoes_coach"]
)

# Ordenar pela soma total de participações (ordem decrescente)
merged_participation = merged_participation.sort_values(by=["participacoes_total","participacoes_player","participacoes_coach","nome"], ascending=False).reset_index(drop=True).head(11)


merged_participation
# Out:
#                   nome  participacoes_player  participacoes_coach  \
# 0           Lucas Rojo                     5                    0
# 1   Leonardo Reginatto                     5                    0
# 2         Andre Rienzo                     4                    1
# 3      Thiago Caldeira                     0                    5
# 4       Oscar Nakaoshi                     4                    0
# 5        Murilo Gouvea                     4                    0
# 6       Hugo Kanabushi                     4                    0
# 7        Reinaldo Sato                     3                    1
# 8        Paulo Orlando                     3                    1
# 9     Marcos Guimaraes                     0                    4
# 10           Vitor Ito                     3                    0
#
#     participacoes_total
# 0                     5
# 1                     5
# 2                     5
# 3                     5
# 4                     4
# ...

# %%
import plotly.graph_objects as go

# Para inverter, criamos a lista invertida de nomes
nomes_invertidos = merged_participation["nome"][::-1]

fig = go.Figure()

fig.add_trace(go.Bar(
    y=merged_participation["nome"],
    x=merged_participation["participacoes_player"],
    name="Jogador",
    marker_color="royalblue",
    orientation='h',
    text=merged_participation["participacoes_player"],
    textposition='inside',
    insidetextanchor='middle',
))

fig.add_trace(go.Bar(
    y=merged_participation["nome"],
    x=merged_participation["participacoes_coach"],
    name="Treinador",
    marker_color="orange",
    orientation='h',
    text=merged_participation["participacoes_coach"],
    textposition='inside',
    insidetextanchor='middle',
))

fig.update_layout(
    barmode="stack",
    title="Participações no WBC",
    xaxis_title="Número de Participações",
    yaxis_title="Nome do Jogagor/Treinador",
    width=800,
    height=500,
    margin=dict(l=150, r=50, t=100, b=50),
    yaxis=dict(
        categoryorder='array',
        categoryarray=nomes_invertidos,
        automargin=True,
        tickfont=dict(size=12),
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Análise da Idade dos Jogadores

# %%
# Criando faixas etárias
bins = [0, 19, 24, 29, 34, 100]
labels = ["<20", "20-24", "25-29", "30-34", "35+"]

# Convertendo para os formatos desejados
df_events_player["idade"] = pd.to_numeric(df_events_player["idade"], errors="coerce")
df_events_player["anoTorneio_str"] = df_events_player["anoTorneio"].astype(str)


# Definindo faixa etária
df_events_player["faixa_etaria"] = pd.cut(df_events_player["idade"], bins=bins, labels=labels, right=True)

# Agrupar: contar jogadores por ano e faixa etária
df_grouped = df_events_player.groupby(["anoTorneio_str", "faixa_etaria"]).size().reset_index(name="quantidade")
# Out:
# <ipython-input-35-ba8d749cd74b>:14: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
df_events_player.head()
# Out:
#    anoTorneio              nome    posicao             time     nivel  \
# 0        2012      Alan Fanhoni  Infielder                -         -
# 1        2012      Andre Rienzo    Pitcher  White Sox Minor  Triple A
# 3        2012      Bruno Hirata    Catcher                -         -
# 4        2012  Carlos Yoshimura    Pitcher                -         -
# 5        2012    Daniel Missaki    Pitcher              NaN       NaN
#
#   altura_m peso_kg bat throw  idade torneio anoTorneio_str faixa_etaria
# 0     1.93    99.8   L     R     21       Q           2012        20-24
# 1     1.91    86.2   R     R     24       Q           2012        20-24
# 3      1.7    87.1   R     R     24       Q           2012        20-24
# 4     1.75    74.8   R     R     28       Q           2012        25-29
# 5     1.83    77.1   R     R     16       Q           2012          <20

# %%
# Função para extrair o nome do jogador mais jovem e mais velho
def get_jogador_extremo(grupo, mais_velho=True):
    if mais_velho:
        return grupo.loc[grupo['idade'].idxmax(), 'nome']
    else:
        return grupo.loc[grupo['idade'].idxmin(), 'nome']

# Agrupando por ano
resumo_idades = df_events_player.groupby('anoTorneio').agg(
    idadeMin=('idade', 'min'),
    idadeMax=('idade', 'max'),
    idadeMedia=('idade', 'mean')
).reset_index()

# Adicionando nomes dos jogadores mais jovem e mais velho
resumo_idades['jogadorMaisJovem'] = df_events_player.groupby('anoTorneio').apply(
    lambda x: get_jogador_extremo(x, mais_velho=False)
).values

resumo_idades['jogadorMaisVelho'] = df_events_player.groupby('anoTorneio').apply(
    lambda x: get_jogador_extremo(x, mais_velho=True)
).values

# Opcional: arredondar a média para uma casa decimal
resumo_idades['idadeMedia'] = resumo_idades['idadeMedia'].round(1)

# Visualizar
resumo_idades
# Out:
# <ipython-input-37-d06d2857b128>:16: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# <ipython-input-37-d06d2857b128>:20: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#    anoTorneio  idadeMin  idadeMax  idadeMedia jogadorMaisJovem  \
# 0        2012        16        40        24.6   Daniel Missaki
# 1        2013        17        41        25.6   Daniel Missaki
# ...

# %%
import plotly.express as px

# Gráfico de linha
fig = px.line(
    df_grouped,
    x="anoTorneio_str",
    y="quantidade",
    color="faixa_etaria",
    markers=True,
    width=700,
    height=500,
    title="Faixa Etária por Edição do Evento",
    labels={
        "anoTorneio_str": "Ano do Torneio",
        "quantidade": "Nº de Jogadores",
        "faixa_etaria": "Faixa Etária"
    }
)


fig.update_layout(xaxis=dict(dtick=1), title_y = 0.85, title_x = 0.5)  # força um tick por ano
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Gerar o boxplot
fig = px.box(
    df_events_player,
    x="anoTorneio_str",
    y="idade",
    points="all",  # exibe todos os pontos além do box
    title="Distribuição da Idade por Edição do Evento",
    width=700,
    height=500,
    labels={"anoTorneio_str": "Edição do Evento", "idade": "Idade dos Jogadores"},
    color="anoTorneio_str"  # opcional: colore por ano
)

fig.update_traces(
    boxpoints='all',
    line=dict(width=4),
    width = 0.3
)


fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Ligas onde já Atuaram

# %%
import plotly.express as px
import plotly.graph_objects as go

# Colunas de ligas
ligas = ['isMLB', 'isNPB', 'isMEX', 'isVEN', 'isMiLB', 'isJPIND']

# De-para das ligas
nomes_ligas = {
    'isMLB': 'MLB',
    'isNPB': 'NPB (Liga Japonesa)',
    'isMEX': 'Liga Mexicana',
    'isVEN': 'Liga Venezuelana',
    'isMiLB': 'MiLB - Minor League',
    'isJPIND': 'Ligas Independentes Japonesas'
}

# Soma total por liga
liga_totais = df_player_list[ligas].sum().reset_index()
liga_totais.columns = ['Liga', 'Quantidade']
liga_totais['Liga'] = liga_totais['Liga'].replace(nomes_ligas)

# Gráfico de pizza
fig_pie = px.pie(
    liga_totais,
    names='Liga',
    values='Quantidade',
    title='Distribuição de Jogadores por Liga Profissional',
    color_discrete_sequence=px.colors.qualitative.Set3,
    width=600,
    height=500,
)

fig_pie.update_layout(
    title_y=0.85  # centraliza o título (0 = esquerda, 1 = direita)
)

# Texto dentro dos setores
fig_pie.update_traces(textposition='inside', textinfo='value')

# Adiciona legenda explicativa no rodapé
fig_pie.add_annotation(
    text="Dados acumulados até 05/2025, independentemente do ano do torneio.",
    xref="paper", yref="paper",
    x=0.5, y=-0.05,  # posição abaixo do gráfico
    showarrow=False,
    font=dict(size=10),
    align="center"
)

fig_pie.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Prepara os dados
df_player_list[ligas] = df_player_list[ligas].fillna(0).astype(int)

# Extrai país do local de nascimento
df_player_list['pais'] = df_player_list['localNascimento'].str.extract(r',\s*(\w+)$', expand=False)

# Agrupa por país
df_pais_ligas = df_player_list.groupby('pais')[ligas].sum().reset_index()

# Remove países sem participação
df_pais_ligas = df_pais_ligas[df_pais_ligas[ligas].sum(axis=1) > 0]

# Ordena países por total
df_pais_ligas['total'] = df_pais_ligas[ligas].sum(axis=1)
df_pais_ligas = df_pais_ligas.sort_values(by='total', ascending=False).drop(columns='total')

# Renomeia coluna
df_pais_ligas = df_pais_ligas.rename(columns={'pais': 'País de Origem'})

# Nomes mais amigáveis para ligas
label_map = {
    'isMLB': 'Americana (MLB)', 'isNPB': 'Japonesa (NPB)', 'isKBO': 'Coreana',
    'isMEX': 'Mexicana', 'isTWN': 'Taiwanesa',
    'isVEN': 'Venezuelana', 'isMiLB': 'Minor (MiLB)',
    'isJPIND': 'Indep. Japonesa'
}

# Formato longo
df_melted = df_pais_ligas.melt(id_vars='País de Origem', value_vars=ligas, var_name='Liga', value_name='Quantidade')
df_melted['Liga'] = df_melted['Liga'].replace(label_map)

# Ordena as ligas pelo total geral (mais usadas no topo)
liga_order = df_melted.groupby('Liga')['Quantidade'].sum().sort_values(ascending=False).index.tolist()
df_melted['Liga'] = pd.Categorical(df_melted['Liga'], categories=liga_order, ordered=True)

# Heatmap com melhorias
fig_heatmap = px.density_heatmap(
    df_melted,
    x="País de Origem",
    y="Liga",
    z="Quantidade",
    color_continuous_scale="YlGnBu",
    title="Número de Jogadores por Liga e País de Nascimento (até 2025)",
    text_auto=True,
    width=800,
    height=520
)

# Layout aprimorado
fig_heatmap.update_layout(
    coloraxis_colorbar_title="N° de Jogadores",
    title_x=0.5,
    margin=dict(l=40, r=40, t=60, b=80),
)

# Adiciona legenda explicativa (rodapé)
fig_heatmap.add_annotation(
    text="Dados acumulados até maio de 2025 — independentemente do ano da convocação.",
    xref="paper", yref="paper",
    x=0.5, y=-0.22,
    showarrow=False,
    font=dict(size=12),
    align="center"
)

fig_heatmap.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Pivot para formato liga x país
df_pivot = df_melted.pivot(index='Liga', columns='País de Origem', values='Quantidade').fillna(0).astype(int)

# Monta lista de valores para o header: 'Liga' + países
header_values = ['Liga'] + df_pivot.columns.tolist()

# Valores para as células: lista com a primeira coluna (liga) + valores das outras colunas (países)
cell_values = [df_pivot.index.tolist()] + [df_pivot[col].tolist() for col in df_pivot.columns]

fig = go.Figure(data=[go.Table(
    header=dict(
        values=header_values,
        fill_color='lightblue',
        align='center',
        font=dict(size=12, color='black'),
        line_color='darkslategray',
    ),
    cells=dict(
        values=cell_values,
        fill_color='white',
        align='center',
        font=dict(size=11, color='black'),
        line_color='darkslategray',
    ),
)])

# Ajusta a largura das colunas (px)
fig.data[0].columnwidth = [150] + [70] * len(df_pivot.columns)

fig.update_layout(
    title_text="Número de Jogadores por Liga e País de Nascimento (até 2025)",
    title_x=0.5,
    title_y=0.9,
    margin=dict(l=40, r=40, t=80, b=40),
    width=650,
    height=500,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
